# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from collections import Counter
from sklearn.decomposition import PCA
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt      
import seaborn as sns

# %%
df = pd.read_csv('laptops3.csv', header=0, sep=',') 
del df['Unnamed: 0']
df
# Out:
#       Company  Entry Date  Operation System  Weight  CPU  Gen  RAM  Storage  \
# 0           8      2021.0                 8    1.65    9   11    8    256.0
# 1           2      2022.0                 8    1.69   10   11    8    256.0
# 2           8      2022.0                 8    1.85    8    4    8    256.0
# 3           1      2022.0                 8    1.80   11   11   16   1000.0
# 4           8      2022.0                 6    1.63   10   12   16    512.0
# ...       ...         ...               ...     ...  ...  ...  ...      ...
# 3180        8      2022.0                 7    1.88   11   12   16   1000.0
# 3181        2      2021.0                 4    2.42   12   11   32   1000.0
# 3182        2      2021.0                 4    2.45   12   11   32   1000.0
# 3183        8      2022.0                 4    1.81   12   11   32   1000.0
# 3184        1      2020.0                 2    2.40   11   10   32   1000.0
#
# ...

# %%
model=LinearRegression()

X=df[df.columns[df.columns != 'Price']]
Y=df[['Price']]
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

model.fit(X_train , Y_train)
Y_pred=regressor.predict(X_test)

# %%
sns.regplot(Y_test, Y_pred, scatter_kws={'color':'teal'}, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
pred=model.score(X_test,Y_test)
train_score = model.score(X_train, Y_train)
print(train_score)
print(pred)
# Out:
# 0.7242441811596503
# 0.6984403587229608

# %%
model=LinearRegression()

X=df[['Company','Entry Date','Weight','CPU','Gen','RAM','Storage','Resolution','Hz','Touch Screen','Graphic Card']]
Y=df[['Price']]
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

model.fit(X_train , Y_train)

Y_pred=model.predict(X_test)

# %%
sns.regplot(Y_test, Y_pred, scatter_kws={'color':'royalblue'}, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
pred=model.score(X_test,Y_test)
train_score = model.score(X_train, Y_train)
print(train_score)
print(pred)
# Out:
# 0.7180412844649078
# 0.6925576350263858

# %%
model=LinearRegression()

X=df[['Entry Date','CPU','Gen','RAM','Storage','Screen Type','Hz','Touch Screen','Graphic Card']]
Y=df[['Price']]
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)
model.fit(X_train , Y_train)

Y_pred=model.predict(X_test)

# %%
sns.regplot(Y_test, Y_pred, scatter_kws={'color':'lightblue'}, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
pred=model.score(X_test,Y_test)
train_score = model.score(X_train, Y_train)
print(train_score)
print(pred)
# Out:
# 0.6974898489150035
# 0.6830230327868829

# %%
df2 = df.copy()
df2[df2['Price']>17000]
# Out:
#       Company  Entry Date  Operation System  Weight  CPU  Gen  RAM  Storage  \
# 2407        2      2022.0                 4    2.60   12   12   32   1000.0
# 2450        8      2022.0                 7    1.94    6    5   32   1000.0
# 2469        2      2022.0                 7    2.51   12   12   64   2000.0
# 2717        2      2022.0                 7    2.51   12   12   64   2000.0
# 2769        8      2022.0                 7    1.81   12   12   32   1000.0
# 2828        8      2022.0                 7    2.95   12   12   32   1000.0
# 2992        2      2022.0                 7    2.67   12   12   32   1000.0
# 3018        2      2022.0                 7    3.01   12   12   32   1000.0
# 3049        2      2022.0                 4    3.05   12   12   32   1000.0
# 3069        8      2022.0                 7    1.88   12   12   32   1000.0
# 3070        8      2022.0                 7    1.81   11   12   32   1000.0
# ...

# %%
df2=df2[df2['Price']<17000]

# %%
model=LinearRegression()

X=df2[df2.columns[df2.columns != 'Price']]
Y=df2[['Price']]
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

model.fit(X_train , Y_train)

Y_pred=model.predict(X_test)

# %%
sns.regplot(Y_test, Y_pred, scatter_kws={'color':'paleturquoise'}, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
pred=model.score(X_test,Y_test)
train_score = model.score(X_train, Y_train)
print(train_score)
print(pred)
# Out:
# 0.7160298281765187
# 0.7305763954284081

# %%
#random Forest:
X=df[df.columns[df.columns != 'Price']]
Y=df[['Price']]
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)
model = RandomForestRegressor(n_estimators=100, random_state=50)
model.fit(X_train, Y_train)
train_score = model.score(X_train, Y_train)
print(train_score)
print(model.score(X_test, Y_test))
# Out:
# 0.9855526719337381
# 0.8853262468432282
